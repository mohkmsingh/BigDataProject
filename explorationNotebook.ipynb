# %%
import pandas as pd
import os
currentDir = os.getcwd()
print("currentDir:", currentDir)

objects_path = "StartupData/objects.csv"

objects_df = pd.read_csv(objects_path)

print(objects_df.head())
print(objects_df.columns)
# Out:
# currentDir: /home/linus/WashUCoding/DIS Copenhagen/Data Science/FinalProject
# /tmp/ipykernel_26836/3164149082.py:8: DtypeWarning: Columns (3,7,9,10,17,18,21,22,23,25,26,29,30,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   objects_df = pd.read_csv(objects_path)
#         id entity_type  entity_id parent_id                name  \
# 0      c:1     Company          1       NaN            Wetpaint
# 1     c:10     Company         10       NaN             Flektor
# 2    c:100     Company        100       NaN               There
# 3  c:10000     Company      10000       NaN             MYWEBBO
# 4  c:10001     Company      10001       NaN  THE Movie Streamer
#
#       normalized_name                    permalink    category_code  \
# 0            wetpaint            /company/wetpaint              web
# 1             flektor             /company/flektor      games_video
# 2               there               /company/there      games_video
# 3             mywebbo             /company/mywebbo  network_hosting
# 4  the movie streamer  /company/the-movie-streamer      games_video
#
#       status  founded_at  ... last_funding_at funding_rounds  \
# 0  operating  2005-10-17  ...      2008-05-19              3
# 1   acquired         NaN  ...             NaN              0
# 2   acquired         NaN  ...             NaN              0
# 3  operating  2008-07-26  ...             NaN              0
# 4  operating  2008-07-26  ...             NaN              0
#
#   funding_total_usd first_milestone_at last_milestone_at  milestones  \
# 0        39750000.0         2010-09-05        2013-09-18           5
# 1               0.0                NaN               NaN           0
# 2               0.0         2003-02-01        2011-09-23           4
# 3               0.0                NaN               NaN           0
# 4               0.0                NaN               NaN           0
#
#    relationships        created_by           created_at           updated_at
# 0             17  initial-importer  2007-05-25 06:51:27  2013-04-13 03:29:00
# 1              6  initial-importer  2007-05-31 21:11:51  2008-05-23 23:23:14
# 2             12  initial-importer  2007-08-06 23:52:45  2013-11-04 02:09:48
# 3              0               NaN  2008-08-24 16:51:57  2008-09-06 14:19:18
# 4              0               NaN  2008-08-24 17:10:34  2008-09-06 14:19:18
#
# [5 rows x 40 columns]
# Index(['id', 'entity_type', 'entity_id', 'parent_id', 'name',
#        'normalized_name', 'permalink', 'category_code', 'status', 'founded_at',
#        'closed_at', 'domain', 'homepage_url', 'twitter_username', 'logo_url',
#        'logo_width', 'logo_height', 'short_description', 'description',
#        'overview', 'tag_list', 'country_code', 'state_code', 'city', 'region',
#        'first_investment_at', 'last_investment_at', 'investment_rounds',
#        'invested_companies', 'first_funding_at', 'last_funding_at',
#        'funding_rounds', 'funding_total_usd', 'first_milestone_at',
#        'last_milestone_at', 'milestones', 'relationships', 'created_by',
#        'created_at', 'updated_at'],
#       dtype='object')

# %%
# generate a series of dictionaries, each with only rows of their own type
# there are 4 types: companies, financial orgs, people, and products
id_to_name_companies = {}
name_to_id_companies = {}

id_to_name_financial_orgs = {}
name_to_id_financial_orgs = {}

id_to_name_people = {}
name_to_id_people = {}

id_to_name_products = {}
name_to_id_products = {}

for index, row in objects_df.iterrows(): 
    id = row["id"]
    name = row["normalized_name"]

    # c: companies
    if id.startswith("c:"): 
        id_to_name_companies[id] = name
        name_to_id_companies[name] = id

    # f: financial orgs
    elif id.startswith("f:"): 
        id_to_name_financial_orgs[id] = name
        name_to_id_financial_orgs[name] = id
    
    # p: people
    elif id.startswith("p:"): 
        id_to_name_people[id] = name
        name_to_id_people[name] = id
    
    # r: products
    elif id.startswith("r:"): 
        id_to_name_products[id] = name
        name_to_id_products[name] = id

# %%
# Example products
print(objects_df["entity_type"].unique())
printedCount = 0
for index, row in objects_df.iterrows(): 
    if printedCount > 10: 
        break 
    if row["entity_type"] == "Product": 
        print(row["normalized_name"])
        printedCount += 1
# Out:
# ['Company' 'FinancialOrg' 'Person' 'Product']
# wikison wetpaint
# slacker web player
# vemo enterprise workforce planning
# dexmo study and revision network
# virtual pbx parachute
# virtual pbx soho
# virtual pbx small business
# shared hosting
# vps hosting
# managed services
# hirebridge recruiter

# %%
# returns a sorted list of tuples, tuple[0] is an integer code, tuple[1] is a name
def generateSortedLists(dictionary): 
    keyVals = []
    prefix = None

    # create a list of tuples without the prefix to the code
    for key, val in dictionary.items(): 
        prefix = key[:2]
        integerKey = int(key[2:]) # loses "c:" or "r:" or "f:"
        keyVals.append((integerKey,  val))

    # sort by numerical code
    keyVals.sort(key=lambda a: a[0])

    # add the prefix back to tuple[0] (the code for an element)
    return list(map(lambda x : (prefix+str(x[0]), x[1]), keyVals))

companyTuples = generateSortedLists(id_to_name_companies)
financialOrgTuples = generateSortedLists(id_to_name_financial_orgs)
peopleTuples = generateSortedLists(id_to_name_people)
productTuples = generateSortedLists(id_to_name_products)

print(companyTuples[:10])
print(financialOrgTuples[:10])
print(peopleTuples[:10])
print(productTuples[:10])
# Out:
# [('c:1', 'wetpaint'), ('c:2', 'adventnet'), ('c:3', 'zoho'), ('c:4', 'digg'), ('c:5', 'facebook'), ('c:7', 'omnidrive'), ('c:8', 'postini'), ('c:9', 'geni'), ('c:10', 'flektor'), ('c:11', 'fox interactive media')]
# [('f:1', 'greylock'), ('f:2', 'omidyar network'), ('f:3', 'trinity ventures'), ('f:4', 'accel'), ('f:5', 'meritechpartners'), ('f:6', 'founders'), ('f:7', 'charles river ventures'), ('f:8', 'centennial ventures'), ('f:10', 'mission ventures'), ('f:11', 'sevin rosen funds')]
# [('p:2', 'ben elowitz'), ('p:3', 'kevin flaherty'), ('p:4', 'raju vegesna'), ('p:5', 'ian wenig'), ('p:6', 'kevin rose'), ('p:7', 'jay adelson'), ('p:8', 'owen byrne'), ('p:9', 'ron gorodetzky'), ('p:10', 'mark zuckerberg'), ('p:11', 'dustin moskovitz')]
# [('r:1', 'wikison wetpaint'), ('r:3', 'photobucket'), ('r:4', 'geni'), ('r:5', 'flektor'), ('r:9', 'gizmoz'), ('r:10', 'slacker web player'), ('r:11', 'slacker desktop radio'), ('r:13', 'slacker portable player'), ('r:14', 'lala'), ('r:15', 'helio')]

# %%
# Let's figure out the most common acquirers
acquistions_path = "StartupData/acquisitions.csv"

acquisitions_df = pd.read_csv(acquistions_path)
acquisitions_df.head()
# Out:
#    id  acquisition_id acquiring_object_id acquired_object_id term_code  \
# 0   1               1                c:11               c:10       NaN
# 1   2               7                c:59               c:72      cash
# 2   3               8                c:24              c:132      cash
# 3   4               9                c:59              c:155      cash
# 4   5              10               c:212              c:215      cash
#
#    price_amount price_currency_code acquired_at  \
# 0    20000000.0                 USD  2007-05-30
# 1    60000000.0                 USD  2007-07-01
# 2   280000000.0                 USD  2007-05-01
# 3   100000000.0                 USD  2007-06-01
# 4    25000000.0                 USD  2007-07-01
#
#                                           source_url  \
# 0  http://venturebeat.com/2007/05/30/fox-interact...
# 1  http://www.techcrunch.com/2007/07/02/deal-is-c...
# 2  http://www.techcrunch.com/2007/05/30/cbs-acqui...
# 3  http://techcrunch.com/2007/05/23/100-million-p...
# 4  http://blog.seattlepi.nwsource.com/venture/arc...
#
#                                   source_description           created_at  \
# 0  Fox Interactive confirms purchase of Photobuck...  2007-05-31 22:19:54
# 1    Deal is Confirmed: Google Acquired GrandCentral  2007-07-03 08:14:50
# 2   CBS Acquires Europeâs Last.fm for $280 million  2007-07-12 04:19:24
# 3  $100 Million Payday For Feedburner  This Deal...  2007-07-13 09:52:59
# 4                                       seatlepi.com  2007-07-20 05:29:07
#
#             updated_at
# 0  2008-05-21 19:23:44
# 1  2011-05-06 21:51:05
# 2  2008-05-19 04:48:50
# 3  2012-06-05 03:22:17
# 4  2008-02-25 00:23:47

# %%
from collections import defaultdict
acquisitions_dict = defaultdict(list)
numKeyErrors = 0
nonNumKeyErrors = 0

for index, row in acquisitions_df.iterrows(): 
    acquiring_object_id = row["acquiring_object_id"]
    acquired_object_id = row["acquired_object_id"]
    acquisition_cost_in_millions = row["price_amount"] // 1_000_000
    # TODO: the below line is throwing an error
    try: 
        acquirerCompanyName = str(id_to_name_companies[acquiring_object_id])
        acquiredCompanyName = str(id_to_name_companies[acquired_object_id])

        acquisitions_dict[acquirerCompanyName].append((acquiredCompanyName, acquisition_cost_in_millions))
        nonNumKeyErrors += 1

    # there are 32 key errors (i.e. 32 company codes with no known associated name)
    except KeyError: 
        # print("Key error on", acquired_object_id)
        numKeyErrors += 1

print("Number of key errors:", numKeyErrors)
print("Number of non-key errors:", nonNumKeyErrors)
print()
reducedDict = {key: len(val) for key, val in acquisitions_dict.items()}
# lambda retrieves key and value
sorted_dict = dict(sorted(reducedDict.items(), key=lambda item: item[1], reverse=True))

# print the 10 companies with the most acquisitions and what they acquired
# 
acquisitionCount = 0
for key, value in sorted_dict.items(): 
    if acquisitionCount > 10: 
        break
    print(key, sorted(acquisitions_dict[key], key=lambda item: item[1], reverse=True))
    acquisitionCount += 1
# Out:
# Number of key errors: 47
# Number of non-key errors: 9515
#
('fineground networks', 0.0), ('m i secure', 0.0), ('netsift', 0.0), ('kiss technology', 0.0), ('sheer networks', 0.0), ('nemo systems', 0.0), ('avisena', 0.0), ('sypixx networks', 0.0), ('audium', 0.0), ('meetinghouse data communications', 0.0), ('arroyo video solutions', 0.0), ('orative', 0.0), ('greenfield networks', 0.0), ('tivella', 0.0), ('reactivity', 0.0), ('spans logic', 0.0), ('cognio', 0.0), ('latigent', 0.0), ('linesider technologies', 0.0), ('inlet technologies', 0.0), ('newscale', 0.0), ('versly', 0.0), ('clearaccess', 0.0), ('truviso', 0.0), ('virtuata', 0.0), ('thinksmart technologies', 0.0), ('rohati systems', 0.0), ('cariden technologies',  ...
# google [('motorola mobility', 12500.0), ('doubleclick', 3100.0), ('youtube', 1650.0), ('waze', 1100.0), ('admob', 750.0), ('ita software', 700.0), ('postini', 625.0), ('admeld', 400.0), ('wildfire a division of google', 350.0), ('slide', 182.0), ('widevine technologies', 160.0), ('zagat', 151.0), ('on2 technologies', 130.0), ('channel intelligence', 125.0), ('dmarc broadcasting', 102.0), ('applied semantics', 102.0), ('feedburner', 100.0), ('meebo', 100.0), ('invite media', 80.0), ('jambool', 70.0), ('global ip solutions', 68.0), ('grandcentral', 60.0), ('android', 50.0), ('aardvark', 50.0), ('flutter', 40.0), ('beatthatquote', 37.0), ('bumptop', 35.0), ('gizmo5', 30.0), ('the dealmap', 30.0), ('endoxon', 28.0), ('docverse', 25.0), ('labpixies', 25.0), ('adscape', 23.0), ('flexycore', 23.0), ('peakstream', 20.0), ('omnisio', 15.0), ('jaiku', 12.0), ('mentorwave technologies', 12.0), ('fflick', 10.0), ('modu', 4.0), ('greenborder', 0.0), ('jotspot', 0.0), ('orion', 0.0), ('neotonic software', 0.0), ('measure map', 0.0), ('panoramio', 0.0), ('keyhole', 0.0), ('zenter', 0.0), ('deja', 0.0), ('outride', 0.0), ('kaltix', 0.0), ('sprinks', 0.0), ('genius labs', 0.0), ('ignite logic', 0.0), ('picasa', 0.0), ('zipdash', 0.0), ('where2', 0.0), ('urchin software', 0.0), ('dodgeball', 0.0), ('reqwireless', 0.0), ('skia', 0.0), ('akwan information technologies', 0.0), ('phatbits', 0.0), ('allpay', 0.0), ('brunet', 0.0), ('upstartle', 0.0), ('last software', 0.0), ('pyra labs', 0.0), ('2web technologies', 0.0), ('neven vision', 0.0), ('trendalyzer', 0.0), ('tonic systems', 0.0), ('marratech', 0.0), ('image america', 0.0), ('zingku', 0.0), ('tnc', 0.0), ('recaptcha', 0.0), ('tnc', 0.0), ('teracent', 0.0), ('appjet', 0.0), ('remail', 0.0), ('picnik', 0.0), ('episodic', 0.0), ('plink solutions', 0.0), ('agnilux', 0.0), ('simplify media', 0.0), ('metaweb technologies', 0.0), ('instantiations', 0.0), ('like', 0.0), ('angstro', 0.0), ('socialdeck', 0.0), ('quiksee', 0.0), ('plannr', 0.0), ('blindtype', 0.0), ('freebase', 0.0), ('ruba', 0.0), ('phonetic arts', 0.0), ('
kexchange', 0.0), ('fasa interactive', 0.0), ('comparenet', 0.0), ('numinous technologies', 0.0), ('jump networks', 0.0), ('shadowfactor software', 0.0), ('omnibrowse', 0.0), ('sendit', 0.0), ('zoomit', 0.0), ('stnc', 0.0), ('softway systems', 0.0), ('entropic', 0.0), ('visio', 0.0), ('peach networks', 0.0), ('bungie software', 0.0), ('netgames', 0.0), ('mongomusic', 0.0), ('pacific microsonics', 0.0), ('great plains software', 0.0), ('ncompass labs', 0.0), ('xdegrees', 0.0), ('assetmetrix', 0.0), ('vexcel', 0.0), ('deepmetrix', 0.0), ('iview multimedia', 0.0), ('gteko', 0.0), ('desktopstandard', 0.0), ('devbiz business solutions', 0.0), ('engyro', 0.0), ('stratature', 0.0), ('90 degree software', 0.0), ('twisted pixel games', 0.0), ('perceptive pixel', 0.0), ('phonefactor', 0.0), ('storsimple', 0.0), ('r2 studios', 0.0), ('metricshub', 0.0), ('inrelease', 0.0), ('avicode', 0.0), ('apiphany', 0.0)]
# ibm [('lotus development', 3500.0), ('netezza', 1700.0), ('sterling commerce', 1400.0), ('kenexa', 1300.0), ('spss', 1200.0), ('trusteer', 800.0), ('unica', 480.0), ('demandtec', 440.0), ('xiv', 300.0), ('guardium', 225.0), ('storwize', 140.0), ('worklight', 70.0), ('csl international', 20.0), ('transitive', 0.0), ('telelogic', 0.0), ('exeros', 0.0), ('infodyne', 0.0), ('diligent technologies', 0.0), ('outblaze', 0.0), ('ounce labs', 0.0), ('redpill solutions', 0.0), ('filesx', 0.0), ('lombardi software', 0.0), ('initiate systems', 0.0), ('intelliden', 0.0), ('cast iron systems', 0.0), ('coremetrics', 0.0), ('bigfix', 0.0), ('blade network technologies', 0.0), ('valchemy', 0.0), ('pss systems', 0.0), ('clarity systems', 0.0), ('mainspring', 0.0), ('crossworlds software', 0.0), ('metamerge', 0.0), ('trellisoft', 0.0), ('holosofx', 0.0), ('pwc consulting', 0.0), ('access360', 0.0), ('eads matra datavision', 0.0), ('tarian software', 0.0), ('rational software', 0.0), ('think dynamics', 0.0), ('aptrix', 0.0), ('crossaccess', 0.0), ('productivity solutions', 0.0), ('green pasture software', 0.0), ('trigo technologies', 0.0), ('candle', 0.0), ('alphablox', 0.0), ('cyanea systems', 0.0), ('venetica', 0.0), ('systemcorp a l g', 0.0), ('liberty insurance services', 0.0), ('maersk data', 0.0), ('keymro', 0.0), ('srd', 0.0), ('corio', 0.0), ('ascential software', 0.0), ('gluecode software', 0.0), ('meiosys', 0.0), ('pureedge solutions', 0.0), ('isogon', 0.0), ('dwl', 0.0), ('datapower technology', 0.0), ('iphrase technologies', 0.0), ('network solutions private limited', 0.0), ('bowstreet', 0.0), ('argus semiconductor software', 0.0), ('cims lab', 0.0), ('viacore', 0.0), ('micromuse', 0.0), ('language analysis systems', 0.0), ('buildforge', 0.0), ('unicorn solutions', 0.0), ('rembo technology', 0.0), ('webify solutions', 0.0), ('global value solutions', 0.0), ('mro software', 0.0), ('filenet', 0.0), ('internet security systems', 0.0), ('palisades technology', 0.0), ('consul risk management international', 0.0), ('vallent', 0.0), ('softek storage solutions', 0.0), ('watchfire', 0.0), ('webdialogs', 0.0), ('datamirror', 0.0), ('princeton softech', 0.0), ('novuscg', 0.0), ('aptsoft', 0.0), ('solid information technology', 0.0), ('cognos', 0.0), ('arsenal digital solutions', 0.0), ('net integration technologies', 0.0), ('encentuate', 0.0), ('platform solutions', 0.0), ('ilog', 0.0), ('tririga', 0.0), ('i2', 0.0), ('algorithmics', 0.0), ('q1 labs', 0.0), ('platform computing', 0.0), ('emptoris', 0.0), ('green hat', 0.0), ('varicent software', 0.0), ('vivisimo', 0.0), ('tealeaf', 0.0), ('butterfly software', 0.0), ('star analytics', 0.0), ('urbancode', 0.0), ('softlayer', 0.0), ('the now factory', 0.0), ('xtify', 0.0), ('fiberlink', 0.0)]
# yahoo [('broadcast', 5040.0), ('geocities', 2870.0), ('overture services', 1630.0), ('tumblr', 1100.0), ('alibaba', 1000.0), ('right media', 850.0), ('kelkoo', 475.0), ('hotjobs', 436.0), ('egroups', 432.0), ('zimbra', 350.0), ('bluelithium', 300.0), ('interclick', 270.0), ('inktomi', 235.0), ('maktoob', 164.0), ('musicmatch', 160.0), ('maven networks', 160.0), ('kimo', 145.0), ('encompass', 130.0), ('alltheweb', 100.0), ('rivals', 100.0), ('verdisoft', 93.0), ('four11', 92.0), ('associated content', 90.0), ('online anywhere', 80.0), ('rockmelt', 65.0), ('dapper', 55.0), ('qwiki', 50.0), ('viaweb', 49.0), ('xobni', 48.0), ('foxytunes', 40.0), ('sold com au', 30.0), ('5to1', 30.0), ('summly', 30.0), ('yoyodyne entertainment', 29.0), ('xoopit', 20.0), ('launch media', 12.0), ('mybloglog', 10.0), ('log me on', 10.0), ('snip it', 10.0), ('hyperparallel', 8.0), ('vivasmart', 8.0), ('upcoming', 1.0), ('net controls', 1.0), ('flickr', 0.0), ('jumpcut', 0.0), ('inquisitor', 0.0), ('indextools', 0.0), ('bix', 0.0), ('classicgames', 0.0), ('adinterax', 0.0), ('whereonearth', 0.0), ('konfabulator', 0.0), ('dialpad', 0.0), ('terespondo', 0.0), ('stadeon', 0.0), ('stata labs', 0.0), ('the all seeing eye', 0.0), ('oddpost', 0.0), ('3721 internet assistant', 0.0), ('cadê', 0.0), ('arthas', 0.0), ('myquest', 0.0), ('sportasy', 0.0), ('webcal', 0.0), ('citizen sports', 0.0), ('koprol', 0.0), ('wuf networks', 0.0), ('webjay', 0.0), ('searchfox', 0.0), ('meedio', 0.0), ('kenet works', 0.0), ('wretch', 0.0), ('buzztracker', 0.0), ('intonow', 0.0), ('delicious', 0.0), ('stamped', 0.0), ('ontheair', 0.0), ('alike', 0.0), ('jybe', 0.0), ('astrid', 0.0), ('gopollgo', 0.0), ('milewise', 0.0), ('loki studios', 0.0), ('playerscale', 0.0), ('ghostbird software', 0.0), ('rondee', 0.0), ('bignoggins productions', 0.0), ('admovate', 0.0), ('ztelic', 0.0), ('lexity', 0.0), ('iq engines', 0.0), ('hitpost', 0.0), ('bread', 0.0), ('lookflow', 0.0), ('skyphrase', 0.0), ('ptch', 0.0), ('evntlive', 0.0), ('quik io', 0.0)]
antation travel', 0.0), ('vacation rentals kingston vacation condo', 0.0), ('vacation rentals myrtle beach travel packages', 0.0), ('vacation rentals kingston resort myrtle beach', 0.0), ('vacation rentals kingston vacation myrtle beach', 0.0), ('vacation rentals kingston plantation golf', 0.0), ('best myrtle beach vacation rentals', 0.0), ('kingston plantation myrtle beach', 0.0), ('vacation rentals kingston plantation', 0.0), ('vacation rentals myrtle beach resorts', 0.0), ('kingston plantation myrtle beach info vacation rentals', 0.0), ('vacation rentals travel agent myrtle beach', 0.0), ('vacation rentals kingston plantation travel packages', 0.0), ('vacation rentals kingston plantation horry county', 0.0), ('vacation rentals kingston plantation vrbo', 0.0), ('kingston plantation vacation rentals', 0 ...
# hewlett packard [('eds', 13900.0), ('autonomy', 10200.0), ('mercury interactive', 4500.0), ('3com', 2700.0), ('3par', 2350.0), ('opsware', 1600.0), ('arcsight', 1500.0), ('palm', 1200.0), ('verifone', 1180.0), ('lefthand networks', 360.0), ('snapfish', 300.0), ('melodeo', 30.0), ('voodoopc', 0.0), ('excelleratehro', 0.0), ('ibrix', 0.0), ('colubris networks', 0.0), ('polyserve', 0.0), ('tabblo', 0.0), ('fortify software', 0.0), ('stratavia', 0.0), ('eon systems', 0.0), ('apollo computer', 0.0), ('applied optoelectronic tech', 0.0), ('avantek', 0.0), ('abb cade', 0.0), ('colorado memory systems', 0.0), ('four pi systems', 0.0), ('metrix network systems', 0.0), ('bt d technologies', 0.0), ('eesof', 0.0), ('versatest', 0.0), ('calan', 0.0), ('convex computer', 0.0), ('elseware', 0.0), ('division', 0.0), ('trellis software controls', 0.0), ('vital technology pte', 0.0), ('prolin', 0.0), ('optimization systems', 0.0), ('heartstream', 0.0), ('scope communications', 0.0), ('open skies', 0.0), ('telegra', 0.0), ('transoft networks', 0.0), ('dazel', 0.0), ('security force software', 0.0), ('qosnetics', 0.0), ('bluestone software', 0.0), ('trinagy', 0.0), ('storageapps', 0.0), ('artivision technologies', 0.0), ('compaq', 0.0), ('pipebeach', 0.0), ('extreme logic', 0.0), ('talking blocks', 0.0), ('persist technologies', 0.0), ('consera software', 0.0), ('triaton', 0.0), ('trulogica', 0.0), ('novadigm', 0.0), ('cec europe service management', 0.0), ('synstar', 0.0), ('cgnz', 0.0), ('appiq', 0.0), ('rlx technologies', 0.0), ('scitex vision', 0.0), ('trustgenix', 0.0), ('pixaco', 0.0), ('peregrine systems', 0.0), ('outerbay technologies', 0.0), ('silverwire holding', 0.0), ('the technology', 0.0), ('knightsbridge solutions', 0.0), ('bitfone', 0.0), ('bristol technology', 0.0), ('arteis', 0.0), ('spi dynamics', 0.0), ('neoware', 0.0), ('macdermid colorspan', 0.0), ('atos origin middle east group', 0.0), ('eyp mission critical facilities', 0.0), ('nur macroprinters', 0.0), ('exstream software', 0.0), ('tower software', 0.0), ('vertica systems', 0.0), ('hiflex software', 0.0)]
# oracle [('bea systems', 8500.0), ('sun microsystems', 7400.0), ('siebel systems', 5850.0), ('taleo', 1900.0), ('rightnow technologies', 1500.0), ('atg art technology group', 1000.0), ('eloqua', 871.0), ('phase forward', 685.0), ('agile software', 495.0), ('bigmachines', 400.0), ('vitrue', 300.0), ('ruleburst holdings', 150.0), ('logicalapps', 0.0), ('netsure telecom', 0.0), ('bridgestream', 0.0), ('bharosa', 0.0), ('mvalent', 0.0), ('primavera systems', 0.0), ('virtual iron software', 0.0), ('conformia software', 0.0), ('skywire software', 0.0), ('adminserver', 0.0), ('global knowledge software', 0.0), ('tacit software', 0.0), ('advanced visual technology', 0.0), ('clearapp', 0.0), ('hyperroll', 0.0), ('silver creek systems', 0.0), ('amberpoint', 0.0), ('secerno', 0.0), ('active reasoning', 0.0), ('passlogix', 0.0), ('netforce', 0.0), ('steltor', 0.0), ('siteworks solutions', 0.0), ('collaxa', 0.0), ('peoplesoft', 0.0), ('oblix', 0.0), ('retek', 0.0), ('timesten', 0.0), ('profitlogic', 0.0), ('g log', 0.0), ('innobase', 0.0), ('thor technologies', 0.0), ('octetstring', 0.0), ('temposoft', 0.0), ('360commerce', 0.0), ('sleepycat software', 0.0), ('hotsip', 0.0), ('portal software', 0.0), ('demantra', 0.0), ('metasolv', 0.0), ('sunopsis', 0.0), ('spl worldgroup', 0.0), ('stellent', 0.0), ('tangosol', 0.0), ('hyperion solutions', 0.0), ('lodestar', 0.0), ('relsys international', 0.0), ('sophoi', 0.0), ('convergin', 0.0), ('fatwire', 0.0), ('pillar data systems', 0.0), ('goahead software', 0.0), ('endeca', 0.0), ('cleartrial', 0.0), ('collective intellect', 0.0), ('involver', 0.0), ('skire', 0.0), ('xsigo', 0.0), ('selectminds', 0.0), ('dataraker', 0.0), ('acme packet', 0.0), ('nimbula', 0.0), ('tekelec international', 0.0), ('inquira', 0.0), ('datanomic', 0.0), ('instantis', 0.0), ('compendium', 0.0), ('bitzer mobile', 0.0)]
# aol [('netscape', 4200.0), ('mapquest', 1100.0), ('bebo', 850.0), ('moviefone', 525.0), ('advertising', 435.0), ('icq', 407.0), ('adap tv', 405.0), ('quigo', 363.0), ('spinner', 320.0), ('the huffington post', 315.0), ('tacoda', 275.0), ('buy at', 125.0), ('nullsoft', 80.0), ('5min media', 65.0), ('userplane', 40.0), ('studionow', 36.0), ('about me', 35.0), ('xdrive', 30.0), ('infointeractive', 28.0), ('surphace', 25.0), ('going', 10.0), ('patch', 7.0), ('truveo', 0.0), ('yedda', 0.0), ('goowy', 0.0), ('third screen media', 0.0), ('adtechiq', 0.0), ('weblogs', 0.0), ('lightningcast', 0.0), ('socialthing', 0.0), ('relegence', 0.0), ('gamedaily', 0.0), ('musicnow', 0.0), ('wildseed', 0.0), ('mailblocks', 0.0), ('singing fish', 0.0), ('evoice', 0.0), ('iamaze', 0.0), ('mmafighting', 0.0), ('emurse', 0.0), ('rally up', 0.0), ('techcrunch', 0.0), ('thing labs', 0.0), ('booklink technologies', 0.0), ('navisoft', 0.0), ('medior', 0.0), ('johnson grace', 0.0), ('imagination network', 0.0), ('global network navigator', 0.0), ('compuserve', 0.0), ('personal library software', 0.0), ('quack', 0.0), ('sphere', 0.0), ('unblab', 0.0), ('pictela', 0.0), ('outside in', 0.0), ('hipster', 0.0), ('when', 0.0), ('certify data systems', 0.0), ('gdgt', 0.0)]
# emc [('isilon systems', 2250.0), ('data domain', 2100.0), ('vmware', 635.0), ('iomega', 213.0), ('scaleio', 200.0), ('network intelligence', 175.0), ('kazeon', 150.0), ('mozy', 76.0), ('pi', 0.0), ('decho', 0.0), ('configuresoft', 0.0), ('wysdm software', 0.0), ('fastscaletechnology', 0.0), ('archer technologies', 0.0), ('verid', 0.0), ('greenplum software', 0.0), ('bus tech', 0.0), ('prisa networks', 0.0), ('legato systems', 0.0), ('documentum', 0.0), ('data general', 0.0), ('softworks', 0.0), ('crosstor software', 0.0), ('filepool', 0.0), ('astrum software', 0.0), ('dantz development', 0.0), ('allocity', 0.0), ('smarts', 0.0), ('rainfinity', 0.0), ('acartus', 0.0), ('captiva software', 0.0), ('internosis', 0.0), ('authentica', 0.0), ('kashya', 0.0), ('interlink group', 0.0), ('nlayers', 0.0), ('proactivity', 0.0), ('rsa security', 0.0), ('neartek', 0.0), ('avamar technologies', 0.0), ('valyd software', 0.0), ('geniant', 0.0), ('x hive', 0.0), ('businessedge solutions', 0.0), ('voyence', 0.0), ('document sciences', 0.0), ('infra', 0.0), ('conchango', 0.0), ('netwitness', 0.0), ('pivotal labs', 0.0), ('xtremio', 0.0), ('syncplicity', 0.0), ('watch4net', 0.0), ('silicium security', 0.0), ('silver tail systems', 0.0), ('likewise software', 0.0), ('aveksa', 0.0)]
# intel [('mcafee', 7680.0), ('infineon technologies', 1400.0), ('wind river', 884.0), ('xircom', 748.0), ('ipivot', 500.0), ('aepona', 80.0), ('omek interactive', 40.0), ('olaworks', 31.0), ('indisys', 26.0), ('cognovision', 25.0), ('sensory networks', 20.0), ('neteffect', 8.0), ('opened hand', 0.0), ('rapidmind', 0.0), ('virtutech', 0.0), ('swiftfoot graphics ab', 0.0), ('mobilian', 0.0), ('voice technologies', 0.0), ('xlnt', 0.0), ('cilk', 0.0), ('chips and technologies', 0.0), ('havok', 0.0), ('conformative systems', 0.0), ('sarvega', 0.0), ('oplus technologies', 0.0), ('envara', 0.0), ('west bay semiconductor', 0.0), ('sparkolor', 0.0), ('lightlogic', 0.0), ('cognet', 0.0), ('vxtel', 0.0), ('cad ul', 0.0), ('ziatech', 0.0), ('datakinetics', 0.0), ('ford microelectronics', 0.0), ('basis communications', 0.0), ('kuck associates', 0.0), ('picazo communications', 0.0), ('giga', 0.0), ('ambient technologies', 0.0), ('thinkit technologies', 0.0), ('parity software development', 0.0), ('netboost', 0.0), ('level one communications', 0.0), ('softcom microsystems', 0.0), ('icat', 0.0), ('shiva', 0.0), ('corollary', 0.0), ('dayna communications', 0.0), ('sysdsoft', 0.0), ('fulcrum microsystems', 0.0), ('whamcloud', 0.0), ('mashery', 0.0), ('kno', 0.0), ('hacker league', 0.0)]
